# %% [markdown]
# # 01 - Análise Exploratória de Dados (EDA)
#
# Dataset: Emergency Triage - Venomous Bites

# %%
import sys
sys.path.append('../src')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from data_processing import load_data, basic_info

sns.set_style('whitegrid')

# %%
# Ajuste o caminho conforme o nome real do arquivo baixado do Kaggle
df = load_data('../data/raw/dataset.csv')
df.head()

# %%
df.info()

# %%
# TODO: substituir 'animal' pelo nome real da coluna alvo
df['animal'].value_counts()

# %%
# Distribuição da variável alvo
plt.figure(figsize=(10, 5))
df['animal'].value_counts().plot(kind='bar')
plt.title('Distribuição das classes (animal)')
plt.tight_layout()
plt.show()

# %%
# Valores faltantes
df.isnull().sum().sort_values(ascending=False)

# %%
# Correlação entre variáveis numéricas
plt.figure(figsize=(12, 10))
sns.heatmap(df.select_dtypes('number').corr(), annot=False, cmap='coolwarm')
plt.title('Correlação entre variáveis numéricas')
plt.show()
