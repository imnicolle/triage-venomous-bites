# %% [markdown]
# # 02 - Pré-processamento dos Dados

# %%
import sys
sys.path.append('../src')

import pandas as pd
from data_processing import (
    load_data, split_features_target, encode_categorical,
    scale_numeric, train_test_split_data
)

# %%
df = load_data('../data/raw/dataset.csv')

# TODO: tratar valores nulos conforme identificado na EDA
# df = df.dropna()  # ou imputação

# TODO: listar colunas categóricas e numéricas reais do dataset
categorical_cols = []  # ex: ['regiao_corpo', 'sexo']
numeric_cols = []      # ex: ['idade', 'tempo_desde_picada', 'frequencia_cardiaca']

df = encode_categorical(df, categorical_cols)
X, y = split_features_target(df)

# %%
X_train, X_test, y_train, y_test = train_test_split_data(X, y)
X_train, X_test, scaler = scale_numeric(X_train, X_test, numeric_cols)

print('Treino:', X_train.shape, ' Teste:', X_test.shape)

# %%
# Salvar dados processados para o notebook de modelagem
X_train.to_csv('../data/processed/X_train.csv', index=False)
X_test.to_csv('../data/processed/X_test.csv', index=False)
y_train.to_csv('../data/processed/y_train.csv', index=False)
y_test.to_csv('../data/processed/y_test.csv', index=False)
